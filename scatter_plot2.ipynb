# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Generamos datos aleatorios
x = np.random.rand(50)
y = np.random.rand(50)

# %%
plt.figure()
plt.scatter(x, y)

plt.title("Gráfico de Dispersión Simple")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")

plt.show()
